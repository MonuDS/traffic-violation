# %% [markdown]
# <a href="https://colab.research.google.com/github/MonuDS/traffic-violation/blob/master/Stop%24Go.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5901, done.
# remote: Total 5901 (delta 0), reused 0 (delta 0), pack-reused 5901
# Receiving objects: 100% (5901/5901), 6.17 MiB | 654.00 KiB/s, done.
# Resolving deltas: 100% (3918/3918), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
# make darknet (build)
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:947:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
#2.DOWNLOAD PRETRAINED YOLOV3 WEIGHTS
# get yolov3 pretrained coco dataset weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-02-25 04:50:56--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  99.3KB/s    in 20m 31s
#
# 2020-02-25 05:11:29 (197 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
cd '/content/darknet'
# Out:
# /content/darknet

# %%
# !python abstract.py cars.mp4 output_video.avi
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
# !python speed_check.py
# Out:
# Creating new tracker 0
# Creating new tracker 1
# Creating new tracker 2
# Creating new tracker 3
# Removing carID 3 from list of trackers.
# Removing carID 3 previous location.
# Removing carID 3 current location.
# Removing carID 1 from list of trackers.
# Removing carID 1 previous location.
# Removing carID 1 current location.
# Creating new tracker 4
# Creating new tracker 5
# Creating new tracker 6
# Removing carID 6 from list of trackers.
# Removing carID 6 previous location.
# Removing carID 6 current location.
# Creating new tracker 7
# Removing carID 5 from list of trackers.
# Removing carID 5 previous location.
# Removing carID 5 current location.
# Removing carID 0 from list of trackers.
# Removing carID 0 previous location.
# Removing carID 0 current location.
# Creating new tracker 8
# Removing carID 4 from list of trackers.
# Removing carID 4 previous location.
# Removing carID 4 current location.
# Creating new tracker 9
# Creating new tracker 10
# ...
